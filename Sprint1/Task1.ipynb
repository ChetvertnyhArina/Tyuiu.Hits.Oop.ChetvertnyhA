// %% [markdown]
// <h1 style="color:DodgerBlue">Структура и объявление класса, через: свойства, геттеры и сеттеры</h1>

// %% [markdown]
// ### Структура и Объявление Класса в C#
//
// В C#, класс объявляется с использованием ключевого слова `class`, за которым следует имя класса. Класс может содержать поля (данные), свойства (способ доступа к данным), методы (функциональность) и события.
//
// #### Свойства
//
// Свойства в C# используются для инкапсуляции данных. Они предоставляют гибкий механизм для чтения, записи или вычисления значений приватных полей. Свойства могут иметь два акцессора: `get` (геттер) для чтения значения и `set` (сеттер) для его изменения.
//
// #### Геттеры и Сеттеры
//
// Геттеры и сеттеры являются частью свойств класса в C#. Геттер (`get`) используется для возврата значения свойства, а сеттер (`set`) — для установки нового значения. Сеттер может включать логику валидации или другие операции перед изменением значения поля.
//
// ### Пример Классов Vehicle и Car
//
// Давайте рассмотрим примеры классов `Vehicle` и `Car`, чтобы проиллюстрировать использование свойств, геттеров и сеттеров, а также разницу между статическими и обычными атрибутами и методами.
//
// #### Класс Vehicle
//
// ```csharp
// public class Vehicle
// {
//     private string _color;
//     private int _speed;
//
//     // Свойство Color с геттером и сеттером
//     public string Color
//     {
//         get { return _color; }
//         set { _color = value; }
//     }
//
//     // Свойство Speed с геттером и сеттером
//     public int Speed
//     {
//         get { return _speed; }
//         set
//         {
//             if (value >= 0)
//                 _speed = value;
//             else
//                 throw new ArgumentOutOfRangeException("Скорость не может быть отрицательной!");
//         }
//     }
//
//     // Статический атрибут
//     public static int TotalVehicles { get; private set; } = 0;
//
//     // Конструктор
//     public Vehicle()
//     {
//         TotalVehicles++;
//     }
//
//     // Обычный метод
//     public void Accelerate(int delta)
//     {
//         Speed += delta;
//     }
//
//     // Статический метод
//     public static void DisplayTotalVehicles()
//     {
//         Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
//     }
// }
// ```
//
// #### Класс Car
//
// ```csharp
// public class Car : Vehicle
// {
//     private int _fuelLevel;
//
//     // Свойство FuelLevel с геттером и сеттером
//     public int FuelLevel
//     {
//         get { return _fuelLevel; }
//         set { _fuelLevel = value; }
//     }
//
//     // Конструктор
//     public Car() : base()
//     {
//         FuelLevel = 100; // Задаем начальный уровень топлива
//     }
//
//     // Обычный метод
//     public void Refuel(int amount)
//     {
//         FuelLevel += amount;
//     }
// }
// ```
//
// ### Разница между Статическими и Обычными Атрибутами и Методами Класса
//
// - **Статические атрибуты и методы** принадлежат самому классу, а не его экземплярам. Они могут быть вызваны без создания объекта класса. В примере выше `TotalVehicles` является статическим атрибутом, а `DisplayTotalVehicles()` — статическим методом класса `Vehicle`.
// - **Обычные атрибуты и методы** принадлежат экземплярам класса и могут иметь разные значения для разных объектов. В примере выше `_color`, `_speed` и `_fuelLevel` являются обычными атрибутами, а методы `Accelerate()` и `Refuel()` — обычными методами.
//
// ### Заключение
//
// В этом таске мы рассмотрели структуру и объявление класса в C#, включая свойства, геттеры и сеттеры, а также разницу между статическими и обычными атрибутами и методами класса на примерах классов `Vehicle` и `Car`. Эти концепции являются основой для создания объектно-ориентированных программ на C#.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Car и Vehicle ниже в блоке:</h4>
//
// ----

// %%
public class Vehicle
{
    private string _color;
    private int _speed;

    public string Color
    {
        get { return _color; }
        set { _color = value; }
    }

    public int Speed
    {
        get { return _speed; }
        set
        {
            if (value >= 0)
                _speed = value;
        }
    }

    public static int TotalVehicles { get; private set; } = 0;

    public Vehicle()
    {
        _color = "Не указан";
        _speed = 0;
        TotalVehicles++;
    }

    public Vehicle(string color, int speed) : this()
    {
        Color = color;
        Speed = speed;
    }

    public void Accelerate(int delta)
    {
        Speed += delta;
    }

    public virtual string Info()
    {
        return $"Транспорт. Цвет: {Color}. Скорость: {Speed} км/ч.";
    }

    public static void DisplayTotalVehicles()
    {
        Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
    }
}

public class Car : Vehicle
{
    private int _fuelLevel;

    public int FuelLevel
    {
        get { return _fuelLevel; }
        set
        {
            if (value >= 0)
                _fuelLevel = value;
        }
    }

    public Car() : base()
    {
        FuelLevel = 100;
    }

    public Car(string color, int speed) : base(color, speed)
    {
        FuelLevel = 100;
    }

    public void Refuel(int amount)
    {
        FuelLevel += amount;
        Console.WriteLine($"Заправлено на {amount}. Топливо: {FuelLevel}");
    }

    public override string Info()
    {
        return $"Автомобиль. Цвет: {Color}. Скорость: {Speed} км/ч. Топливо: {FuelLevel}.";
    }
}



Car myCar = new Car("Красный", 60);
Console.WriteLine(myCar.Info());
myCar.Accelerate(20);
Console.WriteLine(myCar.Info());
myCar.Refuel(15);
Console.WriteLine(myCar.Info());

Console.WriteLine();

Car myCar2 = new Car("Синий", 80);
Console.WriteLine(myCar2.Info());
myCar2.Accelerate(10);
Console.WriteLine(myCar2.Info());
myCar2.Refuel(20);
Console.WriteLine(myCar2.Info());

Console.WriteLine();

Vehicle.DisplayTotalVehicles();
// Out:
// Автомобиль. Цвет: Красный. Скорость: 60 км/ч. Топливо: 100.
// Автомобиль. Цвет: Красный. Скорость: 80 км/ч. Топливо: 100.
// Заправлено на 15. Топливо: 115
// Автомобиль. Цвет: Красный. Скорость: 80 км/ч. Топливо: 115.
//
// Автомобиль. Цвет: Синий. Скорость: 80 км/ч. Топливо: 100.
// Автомобиль. Цвет: Синий. Скорость: 90 км/ч. Топливо: 100.
// Заправлено на 20. Топливо: 120
// Автомобиль. Цвет: Синий. Скорость: 90 км/ч. Топливо: 120.
//
// Общее количество транспортных средств: 2

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (2-3 например Dog, Cat и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также статические и обычными атрибуты и метода класса

// %%
public class Animal
{
    private string _name;
    private int _age;
    private double _weight;

    public string Name
    {
        get { return _name; }
        set { _name = value; }
    }

   
    public int Age
    {
        get { return _age; }
        set
        {
            if (value >= 0)
                _age = value;
        }
    }


    public double Weight
    {
        get { return _weight; }
        set
        {
            if (value > 0)
                _weight = value;
        }
    }


    public static int TotalAnimals { get; private set; } = 0;


    public Animal()
    {
        _name = "Неизвестно";
        _age = 0;
        _weight = 0;
        TotalAnimals++;
    }

    public Animal(string name, int age, double weight) : this()
    {
        Name = name;
        Age = age;
        Weight = weight;
    }


    public void Grow(int years)
    {
        Age += years;
    }


    public virtual string Info()
    {
        return $"Животное. Имя: {Name}. Возраст: {Age} лет. Вес: {Weight} кг.";
    }


    public virtual void Move()
    {
        Console.WriteLine($"{Name} двигается.");
    }


    public static void DisplayTotalAnimals()
    {
        Console.WriteLine($"Всего животных создано: {TotalAnimals}");
    }
}

public class Dog : Animal
{
    private string _breed;

    public string Breed
    {
        get { return _breed; }
        set { _breed = value; }
    }

    public Dog() : base()
    {
        Breed = "Неизвестна";
    }

    public Dog(string name, int age, double weight, string breed) : base(name, age, weight)
    {
        Breed = breed;
    }

    public void Bark()
    {
        Console.WriteLine($"{Name} лает: Гав-гав!");
    }

    public override void Move()
    {
        Console.WriteLine($"{Name} бежит.");
    }
}

public class Cat : Animal
{
    private string _color;

    public string Color
    {
        get { return _color; }
        set { _color = value; }
    }

    public Cat() : base()
    {
        Color = "Не указан";
    }

    public Cat(string name, int age, double weight, string color) : base(name, age, weight)
    {
        Color = color;
    }

    public void Meow()
    {
        Console.WriteLine($"{Name} мяукает: Мяу-мяу!");
    }

    public override void Move()
    {
        Console.WriteLine($"{Name} крадётся.");
    }
}

public class Bird : Animal
{
    private bool _canFly;

    public bool CanFly
    {
        get { return _canFly; }
        set { _canFly = value; }
    }

    public Bird() : base()
    {
        CanFly = true;
    }

    public Bird(string name, int age, double weight, bool canFly) : base(name, age, weight)
    {
        CanFly = canFly;
    }

    public void Fly()
    {
        if (CanFly)
            Console.WriteLine($"{Name} летит!");
        else
            Console.WriteLine($"{Name} не умеет летать.");
    }

    public override void Move()
    {
        Console.WriteLine($"{Name} машет крыльями.");
    }
}



Dog myDog = new Dog("Нора", 2, 10.0, "Немецкая овчарка");
Console.WriteLine("=== Собака ===");
Console.WriteLine($"Имя: {myDog.Name}");
Console.WriteLine($"Возраст: {myDog.Age} года");
Console.WriteLine($"Вес: {myDog.Weight} кг");
Console.WriteLine($"Порода: {myDog.Breed}");
myDog.Bark();
myDog.Move();

Console.WriteLine();

Cat myCat = new Cat("Снежок", 3, 4.5, "Белый");
Console.WriteLine("=== Кот ===");
Console.WriteLine($"Имя: {myCat.Name}");
Console.WriteLine($"Возраст: {myCat.Age} года");
Console.WriteLine($"Вес: {myCat.Weight} кг");
Console.WriteLine($"Цвет: {myCat.Color}");
myCat.Meow();
myCat.Move();

Console.WriteLine();

Bird myBird = new Bird("Гоша", 1, 0.5, true);
Console.WriteLine("=== Птица ===");
Console.WriteLine($"Имя: {myBird.Name}");
Console.WriteLine($"Возраст: {myBird.Age} год");
Console.WriteLine($"Вес: {myBird.Weight} кг");
Console.WriteLine($"Умеет летать: {myBird.CanFly}");
myBird.Fly();
myBird.Move();

Console.WriteLine();

Animal.DisplayTotalAnimals();
// Out:
// === Собака ===
// Имя: Нора
// Возраст: 2 года
// Вес: 10 кг
// Порода: Немецкая овчарка
// Нора лает: Гав-гав!
// Нора бежит.
//
// === Кот ===
// Имя: Снежок
// Возраст: 3 года
// Вес: 4.5 кг
// Цвет: Белый
// Снежок мяукает: Мяу-мяу!
// Снежок крадётся.
//
// === Птица ===
// Имя: Гоша
// Возраст: 1 год
// Вес: 0.5 кг
// Умеет летать: True
// Гоша летит!
// Гоша машет крыльями.
//
// Всего животных создано: 3
